# %% [markdown]
# <a href="https://colab.research.google.com/github/Thonyta17/Econ-5200/blob/main/Lab_1_%22Hello%2C_Pandas%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#step 1
import pandas as pd
import numpy as np

# %%
data = {
    'Country': ['United States','Argentina','Australia','Brazil'],   # Example: ['United States', 'Britain', ...]
    'iso_a3': [],    # Example: ['USA', 'GBR', 'CHN', 'NOR', 'BRA']
    'local_price': [], # Example: [4.79, 2.89, ...]
    'dollar_ex': []    # Example: [1.0, 0.66, ...]
}
